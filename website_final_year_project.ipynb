# %% [markdown]
# <a href="https://colab.research.google.com/github/sagar-bhusan/Final_Year_Project/blob/main/website_final_year_project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.listdir("/content/drive/MyDrive/dataset_copy")
# Out:
# ['0', '1', '2', '3', '4', '5', '6', '7']

# %%
import os

def rename_images(folder_path):
    # Get a list of all files in the folder
    files = os.listdir(folder_path)
    
    for i, file in enumerate(files):
        
        if file.endswith(".jpg") or file.endswith(".png") or file.endswith(".jpeg"):
            # Build the new file name with the format "a_x"
            new_name = f"7_{i}"

            # Get the file extension
            file_ext = os.path.splitext(file)[1]

            # Build the new file path with the renamed file
            new_file_path = os.path.join(folder_path, f"{new_name}{file_ext}")

            # Rename the file
            os.rename(os.path.join(folder_path, file), new_file_path)
            print(f"Renamed {file} to {new_name}{file_ext}")

folder_path = "/content/drive/MyDrive/dataset_copy/7"  # Path to the folder containing the image files

rename_images(folder_path)
# Out:
# Renamed 7_0.jpg to 7_0.jpg
# Renamed 7_1.jpg to 7_1.jpg
# Renamed 7_2.jpg to 7_2.jpg
# Renamed 7_3.jpg to 7_3.jpg
# Renamed 7_4.jpg to 7_4.jpg
# Renamed 7_5.jpg to 7_5.jpg
# Renamed 7_6.jpg to 7_6.jpg
# Renamed 7_7.jpg to 7_7.jpg
# Renamed 7_8.jpg to 7_8.jpg
# Renamed 7_9.jpg to 7_9.jpg
# Renamed 7_10.jpg to 7_10.jpg
# Renamed 7_11.jpg to 7_11.jpg
# Renamed 7_12.jpg to 7_12.jpg
# Renamed 7_13.jpg to 7_13.jpg
# Renamed 7_14.jpg to 7_14.jpg
# Renamed 7_15.jpg to 7_15.jpg
# Renamed 7_16.jpg to 7_16.jpg
# Renamed 7_17.jpg to 7_17.jpg
# Renamed 7_18.jpg to 7_18.jpg
# Renamed 7_19.jpg to 7_19.jpg
# Renamed 7_20.jpg to 7_20.jpg
# Renamed 7_21.jpg to 7_21.jpg
# Renamed 7_22.jpg to 7_22.jpg
# Renamed 7_23.jpg to 7_23.jpg
# Renamed 7_24.jpg to 7_24.jpg
# Renamed 7_25.jpg to 7_25.jpg
# Renamed 7_26.jpg to 7_26.jpg
# Renamed 7_27.jpg to 7_27.jpg
# Renamed 7_28.jpg to 7_28.jpg
# Renamed 7_29.jpg to 7_29.jpg
# Renamed 7_30.jpg to 7_30.jpg
# Renamed 7_31.jpg to 7_31.jpg
# ...

# %%
# %%html
#
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Login Page</title>
#     <style>
#         body, html {
#             font-family: Arial, sans-serif;
#             height: 100%;
#             margin: 0;
#             padding: 0;
#             background: linear-gradient(to bottom, #3da8e6, #f2f2f2);
#         }
#
#         .container {
#             width: 400px;
#             margin: auto auto;
#             padding: 30px;
#             background: #ffffff;
#             border-radius: 30px;
#             box-shadow: 0 2px 5px rgba(252, 252, 252, 0);
#         }
#
#         h2 {
#             text-align: center;
#         }
#
#         .form-group {
#             margin-bottom: 10px;
#         }
#
#         .form-group label {
#             display: block;
#             margin-bottom: 5px;
#             font-weight: bold;
#         }
#
#         .form-group input[type="text"],
#         .form-group input[type="password"] {
#             width: 100%;
#             padding: 10px;
#             border: 1px solid #ccc;
#             border-radius: 4px;
#         }
#
#         .form-group button {
#             width: 100%;
#             padding: 20px;
#             background-color: #3da8e6;
#             border: none;
#             color: #fff;
#             cursor: pointer;
#             border-radius: 10px;
#         }
#
#         .form-group button:hover {
#             background-color: #2776a3fc;
#         }
#
#         /* Captcha styles */
#         .captcha-overlay {
#             position: fixed;
#             top: 0;
#             left: 0;
#             width: 100%;
#             height: 100%;
#             background-color: rgba(0, 0, 0, 0.5);
#             display: flex;
#             justify-content: center;
#             align-items: center;
#             z-index: 999;
#             visibility: hidden;
#         }
#
#         .captcha-modal {
#             background-color: #ffffff;
#             padding: 20px;
#             border-radius: 5px;
#             box-shadow: 0 2px 5px rgba(0, 0, 0, 0.1);
#             display: flex;
#             flex-direction: column;
#             align-items: center;
#         }
#
#         .captcha-grid {
#             display: grid;
#             grid-template-columns: repeat(6, 1fr);
#             grid-gap: 5px;
#             margin-bottom: 10px;
#         }
#
#         .captcha-image {
#             width: 100%;
#             height: auto;
#         }
#
#         .captcha-input {
#             width: 100%;
#             padding: 5px;
#             border: 1px solid #ccc;
#             border-radius: 3px;
#         }
#
#         .captcha-button {
#             margin-top: 10px;
#         }
#
#         #captchaContainer {
#         width: 300px; /* Adjust the width as needed */
#         height: 300px; /* Adjust the height as needed */
#         border: 1px solid #ccc;
#         display: flex;
#         justify-content: center;
#         align-items: center;
#         }
#
#         .captcha-grid {
#         display: grid;
#         grid-template-columns: repeat(3, 1fr);
#         grid-template-rows: repeat(3, 1fr);
#         gap: 10px; /* Adjust the gap between images as needed */
#         }
#
#         .captcha-image {
#         width: 100px;
#         height: 100px;
#         object-fit: cover;
#         }
#
#     </style>
# </head>
# <body>
#     <div class="container">
#         <h2>Login</h2>
#         <div class="form-group">
#             <label for="username">Username:</label>
#             <input type="text" id="username" placeholder="Enter your username">
#         </div>
#         <div class="form-group">
#             <label for="password">Password:</label>
#             <input type="password" id="password" placeholder="Enter your password">
#         </div>
#         <div class="form-group">
#             <button onclick="showCaptcha()">Login</button>
#         </div>
#     </div>
#
#     <div class="captcha-overlay" id="captchaOverlay">
#         <div class="captcha-modal">
#             <div class="captcha-grid" id="captchaGrid"></div>
#             <!-- <input type="text" id="captchaInput" class="captcha-input" placeholder="Enter the captcha solution"> -->
#             <p>Captcha</p>
#             <p>Please select all the Images of Bus</p>
#             <button onclick="verifyCaptcha()" class="captcha-button">Submit</button>
#         </div>
#     </div>
#
#     <div id="captchaContainer">
#         <div id="captchaGrid" class="captcha-grid"></div>
#       </div>
#
#
#     <script>
#         function showCaptcha() {
#             var overlay = document.getElementById("captchaOverlay");
#             overlay.style.visibility = "visible";
#
#             // Generate the captcha grid
#             var captchaGrid = document.getElementById("captchaGrid");
#             captchaGrid.innerHTML = "";
#
#             var rowCount = 3;
#             var columnCount = 3;
#             var folderCount = 8;
#
#             var imageCounts = [662, 355, 503, 304, 733, 819, 375, 317];
#
#
#   for (var row = 0; row < rowCount; row++) {
#     for (var col = 0; col < columnCount; col++) {
#         var folderIndex = Math.floor(Math.random() * folderCount);
#         var imageIndex = Math.floor(Math.random() * imageCounts[folderIndex]);
#         var imageSrc = `dataset_copy/${folderIndex}/${folderIndex}_${imageIndex}.jpg`;
#         var imageElement = document.createElement("img");
#         imageElement.className = "captcha-image";
#         imageElement.src = imageSrc;
#         captchaGrid.appendChild(imageElement);
#     }
# }
#         }
#
#         function verifyCaptcha() {
#             var captchaInput = document.getElementById("captchaInput");
#             var captchaSolution = captchaInput.value;
#
#             // Perform captcha verification logic here
#
#             // Clear the captcha input and hide the overlay
#             captchaInput.value = "";
#             var overlay = document.getElementById("captchaOverlay");
#             overlay.style.visibility = "hidden";
#         }
#     </script>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Login Page</title>
#     <style>
#         body, html {
#             font-family: Arial, sans-serif;
#             height: 100%;
#             margin: 0;
#             padding: 0;
#             background: linear-gradient(to bottom, #3da8e6, #f2f2f2);
#         }
#
#         .container {
#             width: 400px;
#             margin: auto auto;
#             padding: 30px;
#             background: #ffffff;
#             border-radius: 30px;
#             box-shadow: 0 2px 5px rgba(252, 252, 252, 0);
#         }
#
#         h2 {
#             text-align: center;
#         }
#
#         .form-group {
#             margin-bottom: 10px;
#         }
#
#         .form-group label {
#             display: block;
#             margin-bottom: 5px;
#             font-weight: bold;
#         }
#
#         .form-group input[type="text"],
#         .form-group input[type="password"] {
#             width: 100%;
#             padding: 10px;
# ...
